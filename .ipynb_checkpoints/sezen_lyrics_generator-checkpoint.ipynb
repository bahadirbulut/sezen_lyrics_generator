# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.utils as ku 
import numpy as np 
import os

# %%
tokenizer = Tokenizer()
# !wget --no-check-certificate \
#     https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sonnets.txt \
#     -O /tmp/sonnets.txt
data = open('sezen_lyrics.txt').read()

corpus = data.lower().split("\n")


tokenizer.fit_on_texts(corpus)
total_words = len(tokenizer.word_index) + 1

# create input sequences using list of tokens
input_sequences = []
for line in corpus:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)


# pad sequences 
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# create predictors and label
predictors, label = input_sequences[:,:-1],input_sequences[:,-1]

label = ku.to_categorical(label, num_classes=total_words)

# %%
# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "checkpoints/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True)

model = Sequential()
model.add(Embedding(total_words, 100, input_length=max_sequence_len-1))
model.add(Bidirectional(LSTM(150, return_sequences = True)))
model.add(Dropout(0.2))
model.add(LSTM(100))
model.add(Dense(total_words/2, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(total_words, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 110, 100)          874400
# _________________________________________________________________
# bidirectional (Bidirectional (None, 110, 300)          301200
# _________________________________________________________________
# dropout (Dropout)            (None, 110, 300)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               160400
# _________________________________________________________________
# dense (Dense)                (None, 4372)              441572
# _________________________________________________________________
# dense_1 (Dense)              (None, 8744)              38237512
# =================================================================
# Total params: 40,015,084
# Trainable params: 40,015,084
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(predictors, label, epochs=100, callbacks=[cp_callback], verbose=1)

model.save('sezen_lyrics_generator')
model.save('sezen_lyrics_generator_.h5')
# Out:
# Train on 27319 samples
# Epoch 1/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 8.1816 - accuracy: 0.0241
# Epoch 00001: saving model to checkpoints/cp-0001.ckpt
# 27319/27319 [==============================] - 86s 3ms/sample - loss: 8.1811 - accuracy: 0.0241
# Epoch 2/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 7.7011 - accuracy: 0.0265
# Epoch 00002: saving model to checkpoints/cp-0002.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 7.7007 - accuracy: 0.0265
# Epoch 3/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 7.4819 - accuracy: 0.0292
# Epoch 00003: saving model to checkpoints/cp-0003.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 7.4827 - accuracy: 0.0291
# Epoch 4/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 7.2855 - accuracy: 0.0311
# Epoch 00004: saving model to checkpoints/cp-0004.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 7.2847 - accuracy: 0.0312
# Epoch 5/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 7.1112 - accuracy: 0.0333
# Epoch 00005: saving model to checkpoints/cp-0005.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 7.1112 - accuracy: 0.0333
# Epoch 6/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 6.9494 - accuracy: 0.0361
# Epoch 00006: saving model to checkpoints/cp-0006.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 6.9494 - accuracy: 0.0361
# Epoch 7/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 6.8011 - accuracy: 0.0395
# Epoch 00007: saving model to checkpoints/cp-0007.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 6.8014 - accuracy: 0.0395
# Epoch 8/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 6.6315 - accuracy: 0.0424
# Epoch 00008: saving model to checkpoints/cp-0008.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 6.6315 - accuracy: 0.0424
# Epoch 9/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 6.4651 - accuracy: 0.0448
# Epoch 00009: saving model to checkpoints/cp-0009.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 6.4650 - accuracy: 0.0448
# Epoch 10/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 6.2907 - accuracy: 0.0521
# Epoch 00010: saving model to checkpoints/cp-0010.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 6.2909 - accuracy: 0.0522
# Epoch 11/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 6.1153 - accuracy: 0.0609
# Epoch 00011: saving model to checkpoints/cp-0011.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 6.1155 - accuracy: 0.0609
# Epoch 12/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 5.9321 - accuracy: 0.0728
# Epoch 00012: saving model to checkpoints/cp-0012.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 5.9319 - accuracy: 0.0728
# Epoch 13/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 5.7366 - accuracy: 0.0833
# Epoch 00013: saving model to checkpoints/cp-0013.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 5.7367 - accuracy: 0.0833
# Epoch 14/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 5.5267 - accuracy: 0.1037
# Epoch 00014: saving model to checkpoints/cp-0014.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 5.5273 - accuracy: 0.1036
# Epoch 15/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 5.3196 - accuracy: 0.1239
# Epoch 00015: saving model to checkpoints/cp-0015.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 5.3198 - accuracy: 0.1239
# Epoch 16/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 5.1167 - accuracy: 0.1411
# Epoch 00016: saving model to checkpoints/cp-0016.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 5.1168 - accuracy: 0.1410
# Epoch 17/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 4.9168 - accuracy: 0.1646
# Epoch 00017: saving model to checkpoints/cp-0017.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 4.9167 - accuracy: 0.1646
# Epoch 18/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 4.7216 - accuracy: 0.1857
# Epoch 00018: saving model to checkpoints/cp-0018.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 4.7214 - accuracy: 0.1856
# Epoch 19/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 4.5330 - accuracy: 0.2098
# Epoch 00019: saving model to checkpoints/cp-0019.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 4.5335 - accuracy: 0.2097
# Epoch 20/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 4.3623 - accuracy: 0.2342
# Epoch 00020: saving model to checkpoints/cp-0020.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 4.3627 - accuracy: 0.2341
# Epoch 21/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 4.2001 - accuracy: 0.2579
# Epoch 00021: saving model to checkpoints/cp-0021.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 4.2003 - accuracy: 0.2579
# Epoch 22/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 4.0332 - accuracy: 0.2814
# Epoch 00022: saving model to checkpoints/cp-0022.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 4.0342 - accuracy: 0.2813
# Epoch 23/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 3.8938 - accuracy: 0.3037
# Epoch 00023: saving model to checkpoints/cp-0023.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 3.8940 - accuracy: 0.3036
# Epoch 24/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 3.7610 - accuracy: 0.3231
# Epoch 00024: saving model to checkpoints/cp-0024.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 3.7613 - accuracy: 0.3230
# Epoch 25/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 3.6204 - accuracy: 0.3502
# Epoch 00025: saving model to checkpoints/cp-0025.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 3.6207 - accuracy: 0.3502
# Epoch 26/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 3.5059 - accuracy: 0.3690
# Epoch 00026: saving model to checkpoints/cp-0026.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 3.5058 - accuracy: 0.3691
# Epoch 27/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 3.3901 - accuracy: 0.3879
# Epoch 00027: saving model to checkpoints/cp-0027.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 3.3897 - accuracy: 0.3880
# Epoch 28/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 3.2778 - accuracy: 0.4076
# Epoch 00028: saving model to checkpoints/cp-0028.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 3.2782 - accuracy: 0.4075
# Epoch 29/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 3.1757 - accuracy: 0.4287
# Epoch 00029: saving model to checkpoints/cp-0029.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 3.1757 - accuracy: 0.4287
# Epoch 30/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 3.0888 - accuracy: 0.4444
# Epoch 00030: saving model to checkpoints/cp-0030.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 3.0890 - accuracy: 0.4442
# Epoch 31/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.9878 - accuracy: 0.4649
# Epoch 00031: saving model to checkpoints/cp-0031.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 2.9879 - accuracy: 0.4648
# Epoch 32/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.9226 - accuracy: 0.4801
# Epoch 00032: saving model to checkpoints/cp-0032.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 2.9225 - accuracy: 0.4800
# Epoch 33/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.8263 - accuracy: 0.4973
# Epoch 00033: saving model to checkpoints/cp-0033.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 2.8272 - accuracy: 0.4971
# Epoch 34/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.7458 - accuracy: 0.5117
# Epoch 00034: saving model to checkpoints/cp-0034.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 2.7459 - accuracy: 0.5117
# Epoch 35/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.6617 - accuracy: 0.5318
# Epoch 00035: saving model to checkpoints/cp-0035.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 2.6614 - accuracy: 0.5317
# Epoch 36/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.6058 - accuracy: 0.5429
# Epoch 00036: saving model to checkpoints/cp-0036.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 2.6059 - accuracy: 0.5428
# Epoch 37/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.5538 - accuracy: 0.5521
# Epoch 00037: saving model to checkpoints/cp-0037.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 2.5544 - accuracy: 0.5520
# Epoch 38/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.4965 - accuracy: 0.5666
# Epoch 00038: saving model to checkpoints/cp-0038.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 2.4964 - accuracy: 0.5665
# Epoch 39/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.4083 - accuracy: 0.5816
# Epoch 00039: saving model to checkpoints/cp-0039.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 2.4080 - accuracy: 0.5816
# Epoch 40/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.3470 - accuracy: 0.5947
# Epoch 00040: saving model to checkpoints/cp-0040.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 2.3486 - accuracy: 0.5945
# Epoch 41/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.3298 - accuracy: 0.5939
# Epoch 00041: saving model to checkpoints/cp-0041.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 2.3300 - accuracy: 0.5938
# Epoch 42/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.2633 - accuracy: 0.6112
# Epoch 00042: saving model to checkpoints/cp-0042.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 2.2635 - accuracy: 0.6111
# Epoch 43/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.2016 - accuracy: 0.6230
# Epoch 00043: saving model to checkpoints/cp-0043.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 2.2027 - accuracy: 0.6228
# Epoch 44/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.1529 - accuracy: 0.6323
# Epoch 00044: saving model to checkpoints/cp-0044.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 2.1524 - accuracy: 0.6324
# Epoch 45/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.1043 - accuracy: 0.6399
# Epoch 00045: saving model to checkpoints/cp-0045.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 2.1041 - accuracy: 0.6398
# Epoch 46/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.0634 - accuracy: 0.6490
# Epoch 00046: saving model to checkpoints/cp-0046.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 2.0635 - accuracy: 0.6490
# Epoch 47/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.0311 - accuracy: 0.6535
# Epoch 00047: saving model to checkpoints/cp-0047.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 2.0309 - accuracy: 0.6536
# Epoch 48/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 2.0232 - accuracy: 0.6506
# Epoch 00048: saving model to checkpoints/cp-0048.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 2.0233 - accuracy: 0.6506
# Epoch 49/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.9499 - accuracy: 0.6668
# Epoch 00049: saving model to checkpoints/cp-0049.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.9500 - accuracy: 0.6668
# Epoch 50/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.8962 - accuracy: 0.6769
# Epoch 00050: saving model to checkpoints/cp-0050.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.8960 - accuracy: 0.6770
# Epoch 51/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.8691 - accuracy: 0.6813
# Epoch 00051: saving model to checkpoints/cp-0051.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.8695 - accuracy: 0.6811
# Epoch 52/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.8287 - accuracy: 0.6900
# Epoch 00052: saving model to checkpoints/cp-0052.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.8294 - accuracy: 0.6899
# Epoch 53/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.8212 - accuracy: 0.6882
# Epoch 00053: saving model to checkpoints/cp-0053.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.8210 - accuracy: 0.6883
# Epoch 54/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.7817 - accuracy: 0.6943
# Epoch 00054: saving model to checkpoints/cp-0054.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.7818 - accuracy: 0.6942
# Epoch 55/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.7390 - accuracy: 0.7026
# Epoch 00055: saving model to checkpoints/cp-0055.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.7392 - accuracy: 0.7025
# Epoch 56/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.7207 - accuracy: 0.7067
# Epoch 00056: saving model to checkpoints/cp-0056.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.7214 - accuracy: 0.7066
# Epoch 57/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.6930 - accuracy: 0.7095
# Epoch 00057: saving model to checkpoints/cp-0057.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.6934 - accuracy: 0.7095
# Epoch 58/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.6615 - accuracy: 0.7170
# Epoch 00058: saving model to checkpoints/cp-0058.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.6619 - accuracy: 0.7169
# Epoch 59/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.6442 - accuracy: 0.7189
# Epoch 00059: saving model to checkpoints/cp-0059.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.6442 - accuracy: 0.7189
# Epoch 60/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.6423 - accuracy: 0.7184
# Epoch 00060: saving model to checkpoints/cp-0060.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.6433 - accuracy: 0.7182
# Epoch 61/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.6031 - accuracy: 0.7246
# Epoch 00061: saving model to checkpoints/cp-0061.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.6032 - accuracy: 0.7247
# Epoch 62/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.5619 - accuracy: 0.7311
# Epoch 00062: saving model to checkpoints/cp-0062.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.5615 - accuracy: 0.7312
# Epoch 63/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.5441 - accuracy: 0.7355
# Epoch 00063: saving model to checkpoints/cp-0063.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.5440 - accuracy: 0.7354
# Epoch 64/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.5252 - accuracy: 0.7375
# Epoch 00064: saving model to checkpoints/cp-0064.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.5251 - accuracy: 0.7375
# Epoch 65/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.5210 - accuracy: 0.7381
# Epoch 00065: saving model to checkpoints/cp-0065.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.5213 - accuracy: 0.7379
# Epoch 66/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.4863 - accuracy: 0.7436
# Epoch 00066: saving model to checkpoints/cp-0066.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.4862 - accuracy: 0.7436
# Epoch 67/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.4701 - accuracy: 0.7453
# Epoch 00067: saving model to checkpoints/cp-0067.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.4699 - accuracy: 0.7454
# Epoch 68/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.4482 - accuracy: 0.7510
# Epoch 00068: saving model to checkpoints/cp-0068.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.4484 - accuracy: 0.7508
# Epoch 69/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.4333 - accuracy: 0.7536
# Epoch 00069: saving model to checkpoints/cp-0069.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.4334 - accuracy: 0.7537
# Epoch 70/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.4366 - accuracy: 0.7523
# Epoch 00070: saving model to checkpoints/cp-0070.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.4361 - accuracy: 0.7524
# Epoch 71/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.3975 - accuracy: 0.7551
# Epoch 00071: saving model to checkpoints/cp-0071.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.3975 - accuracy: 0.7551
# Epoch 72/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.3825 - accuracy: 0.7588
# Epoch 00072: saving model to checkpoints/cp-0072.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.3829 - accuracy: 0.7588
# Epoch 73/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.3623 - accuracy: 0.7622
# Epoch 00073: saving model to checkpoints/cp-0073.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.3625 - accuracy: 0.7622
# Epoch 74/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.3454 - accuracy: 0.7633
# Epoch 00074: saving model to checkpoints/cp-0074.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.3458 - accuracy: 0.7632
# Epoch 75/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.3329 - accuracy: 0.7670
# Epoch 00075: saving model to checkpoints/cp-0075.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.3326 - accuracy: 0.7670
# Epoch 76/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.3146 - accuracy: 0.7687
# Epoch 00076: saving model to checkpoints/cp-0076.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.3152 - accuracy: 0.7686
# Epoch 77/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.3144 - accuracy: 0.7675
# Epoch 00077: saving model to checkpoints/cp-0077.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.3145 - accuracy: 0.7675
# Epoch 78/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.2991 - accuracy: 0.7695
# Epoch 00078: saving model to checkpoints/cp-0078.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.2991 - accuracy: 0.7695
# Epoch 79/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.2741 - accuracy: 0.7751
# Epoch 00079: saving model to checkpoints/cp-0079.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.2740 - accuracy: 0.7751
# Epoch 80/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.2628 - accuracy: 0.7765
# Epoch 00080: saving model to checkpoints/cp-0080.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.2626 - accuracy: 0.7765
# Epoch 81/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.2525 - accuracy: 0.7752
# Epoch 00081: saving model to checkpoints/cp-0081.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.2525 - accuracy: 0.7752
# Epoch 82/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.2396 - accuracy: 0.7777
# Epoch 00082: saving model to checkpoints/cp-0082.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.2397 - accuracy: 0.7777
# Epoch 83/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.2414 - accuracy: 0.7770
# Epoch 00083: saving model to checkpoints/cp-0083.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.2412 - accuracy: 0.7772
# Epoch 84/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.2244 - accuracy: 0.7798
# Epoch 00084: saving model to checkpoints/cp-0084.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.2252 - accuracy: 0.7796
# Epoch 85/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.2171 - accuracy: 0.7807
# Epoch 00085: saving model to checkpoints/cp-0085.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.2170 - accuracy: 0.7807
# Epoch 86/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.1952 - accuracy: 0.7855
# Epoch 00086: saving model to checkpoints/cp-0086.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.1950 - accuracy: 0.7855
# Epoch 87/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.1849 - accuracy: 0.7850
# Epoch 00087: saving model to checkpoints/cp-0087.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.1849 - accuracy: 0.7850
# Epoch 88/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.1780 - accuracy: 0.7874
# Epoch 00088: saving model to checkpoints/cp-0088.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.1784 - accuracy: 0.7873
# Epoch 89/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.1767 - accuracy: 0.7845
# Epoch 00089: saving model to checkpoints/cp-0089.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.1767 - accuracy: 0.7844
# Epoch 90/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.1612 - accuracy: 0.7883
# Epoch 00090: saving model to checkpoints/cp-0090.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.1607 - accuracy: 0.7884
# Epoch 91/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.1471 - accuracy: 0.7900
# Epoch 00091: saving model to checkpoints/cp-0091.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.1466 - accuracy: 0.7901
# Epoch 92/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.1390 - accuracy: 0.7924
# Epoch 00092: saving model to checkpoints/cp-0092.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.1391 - accuracy: 0.7924
# Epoch 93/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.1311 - accuracy: 0.7927
# Epoch 00093: saving model to checkpoints/cp-0093.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.1312 - accuracy: 0.7927
# Epoch 94/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.1260 - accuracy: 0.7916
# Epoch 00094: saving model to checkpoints/cp-0094.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.1264 - accuracy: 0.7915
# Epoch 95/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.1101 - accuracy: 0.7949
# Epoch 00095: saving model to checkpoints/cp-0095.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.1098 - accuracy: 0.7949
# Epoch 96/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.1053 - accuracy: 0.7955
# Epoch 00096: saving model to checkpoints/cp-0096.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.1057 - accuracy: 0.7955
# Epoch 97/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.1032 - accuracy: 0.7955
# Epoch 00097: saving model to checkpoints/cp-0097.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.1039 - accuracy: 0.7954
# Epoch 98/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.0945 - accuracy: 0.7954
# Epoch 00098: saving model to checkpoints/cp-0098.ckpt
# 27319/27319 [==============================] - 78s 3ms/sample - loss: 1.0940 - accuracy: 0.7955
# Epoch 99/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.0910 - accuracy: 0.7952
# Epoch 00099: saving model to checkpoints/cp-0099.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.0911 - accuracy: 0.7951
# Epoch 100/100
# 27296/27319 [============================>.] - ETA: 0s - loss: 1.0718 - accuracy: 0.7984
# Epoch 00100: saving model to checkpoints/cp-0100.ckpt
# 27319/27319 [==============================] - 79s 3ms/sample - loss: 1.0715 - accuracy: 0.7985
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: sezen_lyrics_generator/assets

# %%
# %%bash
# # tar -czf archive.tar.gz checkpoints
# tar -czf archive.tar.gz sezen_lyrics_generator

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
loss = history.history['loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.title('Training accuracy')

plt.figure()

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.title('Training loss')
plt.legend()

plt.show()

# %%
seed_text = "Beni benimle birak, sensiz daha iyiyim"
next_words = 100
  
for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted = model.predict_classes(token_list, verbose=0)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word
print(seed_text)
# Out:
# Beni benimle birak, sensiz daha iyiyim öfke olmaz 'kurabiye gibi yağmur uçur ki duvarda fotoğraflar mitem etmeden sonra bıraktığın bir neye kime her gün bak dolu şerefe aşksın sen a hey hey kalbim oda satırlara beş geçen kendimi kendi gözümde yaralanmış ömrüme biraz yıllık et aşka ağrı yok olsun düşün ölmeden inatçı yağmurları söylendi bir dur başladı bak da firuze da geçer da geçer yalan çiçekler o kısası o kısası uyumu dostlar bahtını versen yetmez birbirine eş odun bir vedayla son buldu solmuş ayrı kalp kırmadın mı ilmim mi yalan ölmeden hatırlamak 3x dikenine sabahlar diye başıma geh geh geğirip şişer yapılır ve mesafeler da firuze
